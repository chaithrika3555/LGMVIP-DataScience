# %% [markdown]
# # Task 5
#  **Exploratory Data Analysis on Dataset-Terrorism**
#
# As a security/defense analyst, try to find out the hot zone of terrorism.
# You can choose any of the tool of your choice(Python/R/Tableau/PowerBI/Excel/SAP/
# SAS)
#
# Watch Tutorial from here https://youtu.be/CBCfOTePVPo
#
#  Dataset : https://bit.ly/2TK5Xn5

# %% [markdown]
# **Importing the necessary libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# **Loading the dataset**

# %%
import pandas as pd 
df=pd.read_csv("/content/drive/MyDrive/datasets/globalterrorismdb_0718dist.csv",encoding='latin1')
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region                   region_txt  \
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#Finding null values

df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#Delete unnecessary columns

drop_col = df.isnull().sum()[df.isnull().sum()>(35/100 * df.shape[0])]
drop_col
# Out:
# approxdate     172452
# resolution     179471
# location       126196
# summary         66129
# alternative    152680
#                 ...
# addnotes       153402
# scite1          66191
# scite2         104758
# scite3         138175
# related        156653
# Length: 87, dtype: int64

# %% [markdown]
# **Dropped Columns**

# %%
drop_col.index
# Out:
# Index(['approxdate', 'resolution', 'location', 'summary', 'alternative',
#        'alternative_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3',
#        'attacktype3_txt', 'targtype2', 'targtype2_txt', 'targsubtype2',
#        'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
#        'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt',
#        'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gsubname', 'gname2',
#        'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain2',
#        'guncertain3', 'nperps', 'nperpcap', 'claimed', 'claimmode',
#        'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt', 'claim3',
#        'claimmode3', 'claimmode3_txt', 'compclaim', 'weaptype2',
#        'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt', 'weaptype3',
#        'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt', 'weaptype4',
#        'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt', 'weapdetail',
# ...

# %% [markdown]
# **Dataset after dropping such columns**

# %%
df.drop(drop_col.index, axis = 1, inplace = True)
df.isnull().sum()
# Out:
# eventid                 0
# iyear                   0
# imonth                  0
# iday                    0
# extended                0
# country                 0
# country_txt             0
# region                  0
# region_txt              0
# provstate             421
# city                  434
# latitude             4556
# longitude            4557
# specificity             6
# vicinity                0
# crit1                   0
# crit2                   0
# crit3                   0
# doubtterr               1
# multiple                1
# success                 0
# suicide                 0
# attacktype1             0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# targsubtype1        10373
# targsubtype1_txt    10373
# corp1               42550
# target1               636
# natlty1              1559
# natlty1_txt          1559
# gname                   0
# guncertain1           380
# individual              0
# ...

# %%
df.corr()
# Out:
#                eventid     iyear    imonth      iday  extended   country  \
# eventid       1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear         0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth        0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday          0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended      0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# country      -0.135039 -0.135023 -0.006305  0.003468 -0.020466  1.000000
# region        0.401371  0.401384 -0.002999  0.009710  0.038389  0.148597
# latitude      0.166886  0.166933 -0.015978  0.003423 -0.024749  0.178567
# longitude     0.003907  0.003917 -0.003880 -0.002285  0.000523 -0.000269
# specificity   0.030641  0.030626  0.003621 -0.006991  0.057897 -0.084599
# vicinity      0.070646  0.070659 -0.004501 -0.005367  0.017784 -0.012291
# crit1         0.002019  0.001995  0.001568  0.011434 -0.015029 -0.006646
# ...

# %%
country = pd.DataFrame(df["country_txt"].value_counts())
print("Countries affected most by the attacks: \n")
country.head(5)
# Out:
# Countries affected most by the attacks:
#              country_txt
# Iraq               24636
# Pakistan           14368
# Afghanistan        12731
# India              11960
# Colombia            8306

# %%
region = pd.DataFrame(df["region_txt"].value_counts())
print("Regions affected most by the attacks: \n")
region.head()
# Out:
# Regions affected most by the attacks:
#                             region_txt
# Middle East & North Africa       50474
# South Asia                       44974
# South America                    18978
# Sub-Saharan Africa               17550
# Western Europe                   16639

# %%
city = pd.DataFrame(df["city"].value_counts())
print("Cities affected most by the attacks: \n")
city.head(6)
# Out:
# Cities affected most by the attacks:
#          city
# Unknown  9775
# Baghdad  7589
# Karachi  2652
# Lima     2359
# Mosul    2265
# Belfast  2171

# %%
years = pd.DataFrame(df["iyear"].value_counts())
years
# Out:
#       iyear
# 2014  16903
# 2015  14965
# 2016  13587
# 2013  12036
# 2017  10900
# 2012   8522
# 2011   5076
# 1992   5071
# 2010   4826
# 2008   4805
# 2009   4721
# 1991   4683
# 1989   4324
# 1990   3887
# 1988   3721
# 1984   3495
# 1994   3456
# 2007   3242
# 1997   3197
# 1987   3183
# 1995   3081
# 1996   3058
# 1985   2915
# 1983   2870
# 1986   2860
# 2006   2758
# 1979   2662
# 1980   2662
# 1981   2586
# 1982   2544
# 2005   2017
# 2001   1906
# 2000   1814
# 1978   1526
# 1999   1395
# 2002   1333
# 1977   1319
# 2003   1278
# 2004   1166
# 1998    934
# 1976    923
# 1975    740
# 1970    651
# 1974    581
# 1972    568
# 1973    473
# 1971    471

# %%
month = pd.DataFrame(df["imonth"].value_counts())
month
# Out:
#     imonth
# 5    16875
# 7    16268
# 8    15800
# 10   15563
# 6    15359
# 3    15257
# 4    15152
# 1    14936
# 11   14906
# 9    14180
# 2    13879
# 12   13496
# 0       20

# %%
days = pd.DataFrame(df["iday"].value_counts())
days
# Out:
#     iday
# 15  6500
# 1   6344
# 4   6153
# 16  6112
# 10  6064
# 9   6057
# 13  6043
# 14  6028
# 28  6027
# 12  6012
# 3   6011
# 7   5997
# 19  5973
# 2   5954
# 27  5937
# 11  5936
# 20  5930
# 18  5880
# 25  5875
# 8   5859
# 17  5852
# 5   5844
# 21  5827
# 26  5823
# 22  5799
# 23  5782
# 6   5781
# 24  5752
# 29  5507
# 30  5046
# 31  3095
# 0    891

# %%
attacks = pd.DataFrame(df["attacktype1_txt"].value_counts())
attacks
# Out:
#                                      attacktype1_txt
# Bombing/Explosion                              88255
# Armed Assault                                  42669
# Assassination                                  19312
# Hostage Taking (Kidnapping)                    11158
# Facility/Infrastructure Attack                 10356
# Unknown                                         7276
# Unarmed Assault                                 1015
# Hostage Taking (Barricade Incident)              991
# Hijacking                                        659

# %%
lat = pd.DataFrame(df["latitude"].value_counts())
lat
# Out:
#             latitude
#  33.303566      7521
#  24.891115      2686
# -11.967368      2401
#  36.354145      2247
#  54.607712      2189
# ...              ...
#  32.715659         1
#  32.732875         1
#  32.901412         1
#  33.749892         1
#  6.900742          1
#
# [48322 rows x 1 columns]

# %%
log = pd.DataFrame(df["longitude"].value_counts())
log
# Out:
#              longitude
#  44.371773        7521
#  67.143311        2686
# -76.978462        2401
#  43.143570        2247
# -5.956210         2189
# ...                ...
# -75.682500           1
#  86.984512           1
# -1.207524            1
#  64.522430           1
#  124.437908          1
#
# [48039 rows x 1 columns]

# %%
target = pd.DataFrame(df["targtype1_txt"].value_counts())
target
# Out:
#                                 targtype1_txt
# Private Citizens & Property             43511
# Military                                27984
# Police                                  24506
# Government (General)                    21283
# Business                                20669
# Transportation                           6799
# Utilities                                6023
# Unknown                                  5898
# Religious Figures/Institutions           4440
# Educational Institution                  4322
# Government (Diplomatic)                  3573
# Terrorists/Non-State Militia             3039
# Journalists & Media                      2948
# Violent Political Party                  1866
# Airports & Aircraft                      1343
# Telecommunication                        1009
# NGO                                       970
# Tourists                                  440
# Maritime                                  351
# ...

# %%
sub_target = pd.DataFrame(df["targsubtype1_txt"].value_counts())
sub_target.head()
# Out:
#                                                     targsubtype1_txt
# Unnamed Civilian/Unspecified                                   11596
# Police Security Forces/Officers                                11178
# Military Unit/Patrol/Convoy                                     8277
# Military Personnel (soldiers, troops, officers,...              7963
# Government Personnel (excluding police, military)               6610

# %%
weapon = pd.DataFrame(df["weaptype1_txt"].value_counts())
weapon
# Out:
#                                                     weaptype1_txt
# Explosives                                                  92426
# Firearms                                                    58524
# Unknown                                                     15157
# Incendiary                                                  11135
# Melee                                                        3655
# Chemical                                                      321
# Sabotage Equipment                                            141
# Vehicle (not to include vehicle-borne explosive...            136
# Other                                                         114
# Biological                                                     35
# Fake Weapons                                                   33
# Radiological                                                   14

# %%
sub_weapon = pd.DataFrame(df["weapsubtype1_txt"].value_counts())
sub_weapon
# Out:
#                                            weapsubtype1_txt
# Unknown Explosive Type                                44980
# Unknown Gun Type                                      33137
# Automatic or Semi-Automatic Rifle                     17412
# Vehicle                                                9900
# Projectile (rockets, mortars, RPGs, etc.)              9848
# Other Explosive Type                                   7304
# Handgun                                                6704
# Grenade                                                5167
# Landmine                                               4251
# Arson/Fire                                             4141
# Suicide (carried bodily by human being)                3245
# Remote Trigger                                         2719
# Knife or Other Sharp Object                            2585
# Sticky Bomb                                            1594
# Molotov Cocktail/Petrol Bomb                           1239
# ...

# %%
df["success"].value_counts()
# Out:
# 1    161632
# 0     20059
# Name: success, dtype: int64

# %%
df["suicide"].value_counts()
# Out:
# 0    175058
# 1      6633
# Name: suicide, dtype: int64

# %% [markdown]
# **Conclusion:** South Asian countries such are Iraq, India, Afghanistan, Pakistan are more suffering from terrorism.
#
# Most affected Country: Iraq
#
# Most affected city: Bagdad
#
# Most affected region: Middle East and North Africa
#
# Most terrific year: 1984
#
# Most attack type: Bombing and Explosion
#
# They were success more no. of times in their attacks
